# %%
import requests
import pandas as pd
from datetime import date, datetime
from pprint import pprint as pp

# %%
BASE_URL = "https://api.carbonintensity.org.uk/regional/intensity"
# added base url for sending request to an API.

# %%
last_half_hour = requests.get(BASE_URL).json()["data"][0]
# pp(last_half_hour['from'])
# pp(last_half_hour['intensity'])
print(last_half_hour['regions'][0]['dnoregion'])
pp(last_half_hour)

# %%
start = date(2024, 1, 1)
end = date(2024, 1, 3)

int_date_range = requests.get(f"{BASE_URL}/{start}/{end}").json()["data"]
# pp(int_date_range)
int_date_range
# Out:
# [{'from': '2023-12-31T23:30Z',
#   'to': '2024-01-01T00:00Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 4, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.8},
#      {'fuel': 'nuclear', 'perc': 6.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 44.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 47.4}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 24, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.7},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0.1},
#      {'fuel': 'gas', 'perc': 4.8},
#      {'fuel': 'nuclear', 'perc': 58.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 32.7}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 4, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.9},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.8},
#      {'fuel': 'nuclear', 'perc': 41.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 57.1}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 17, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 9.4},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 2.3},
#      {'fuel': 'gas', 'perc': 1.4},
#      {'fuel': 'nuclear', 'perc': 73.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 13.1}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 83, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 25},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 13.4},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 61.6}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 30, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 7.4},
#      {'fuel': 'nuclear', 'perc': 11.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.3},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 79.2}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 86, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 21.7},
#      {'fuel': 'nuclear', 'perc': 0.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 77.3}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 52, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.5},
#      {'fuel': 'coal', 'perc': 1.9},
#      {'fuel': 'imports', 'perc': 1.1},
#      {'fuel': 'gas', 'perc': 7.7},
#      {'fuel': 'nuclear', 'perc': 20.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 65.8}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 128, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.3},
#      {'fuel': 'coal', 'perc': 6},
#      {'fuel': 'imports', 'perc': 3},
#      {'fuel': 'gas', 'perc': 15.8},
#      {'fuel': 'nuclear', 'perc': 4.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.2}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 19, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.5},
#      {'fuel': 'gas', 'perc': 2.6},
#      {'fuel': 'nuclear', 'perc': 20.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.4}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 281, 'index': 'very high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0.2},
#      {'fuel': 'imports', 'perc': 1.4},
#      {'fuel': 'gas', 'perc': 70.9},
#      {'fuel': 'nuclear', 'perc': 0.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 27}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 118, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2},
#      {'fuel': 'coal', 'perc': 2},
#      {'fuel': 'imports', 'perc': 23.5},
#      {'fuel': 'gas', 'perc': 22.8},
#      {'fuel': 'nuclear', 'perc': 3.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 45.3}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 43, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 26.4},
#      {'fuel': 'gas', 'perc': 8.5},
#      {'fuel': 'nuclear', 'perc': 11.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 53.2}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 75, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 44.2},
#      {'fuel': 'gas', 'perc': 16.1},
#      {'fuel': 'nuclear', 'perc': 0.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 37.9}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 69, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.7},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 10.1},
#      {'fuel': 'gas', 'perc': 12.2},
#      {'fuel': 'nuclear', 'perc': 19.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 52.6}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 25, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.8},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 0.7},
#      {'fuel': 'gas', 'perc': 5.7},
#      {'fuel': 'nuclear', 'perc': 29.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 16.8},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 45.6}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 59, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 15},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 85}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 63, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 8.2},
#      {'fuel': 'gas', 'perc': 11.6},
#      {'fuel': 'nuclear', 'perc': 19},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 53.9}]}]},
#  {'from': '2024-01-01T00:00Z',
#   'to': '2024-01-01T00:30Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 3, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 4.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 44.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 50}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 23, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.4},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4.8},
#      {'fuel': 'nuclear', 'perc': 54.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 37.2}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 3, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 40.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 57.9}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 16, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 9.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0.7},
#      {'fuel': 'gas', 'perc': 1.2},
#      {'fuel': 'nuclear', 'perc': 76.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 12.3}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 83, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 24.8},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 13.4},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 61.8}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 30, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 7.5},
#      {'fuel': 'nuclear', 'perc': 12.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 79.2}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 94, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 23.6},
#      {'fuel': 'nuclear', 'perc': 1.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.5},
#      {'fuel': 'wind', 'perc': 73.9}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 51, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.3},
#      {'fuel': 'coal', 'perc': 1.8},
#      {'fuel': 'imports', 'perc': 0.8},
#      {'fuel': 'gas', 'perc': 7.7},
#      {'fuel': 'nuclear', 'perc': 20.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.2},
#      {'fuel': 'solar', 'perc': 0.4},
#      {'fuel': 'wind', 'perc': 65.8}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 133, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.6},
#      {'fuel': 'coal', 'perc': 5.9},
#      {'fuel': 'imports', 'perc': 2.6},
#      {'fuel': 'gas', 'perc': 17.2},
#      {'fuel': 'nuclear', 'perc': 4.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 63}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 19, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.2},
#      {'fuel': 'gas', 'perc': 2.7},
#      {'fuel': 'nuclear', 'perc': 20},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.2},
#      {'fuel': 'wind', 'perc': 64.8}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 277, 'index': 'very high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#      {'fuel': 'coal', 'perc': 0.2},
#      {'fuel': 'imports', 'perc': 1.7},
#      {'fuel': 'gas', 'perc': 69.5},
#      {'fuel': 'nuclear', 'perc': 0.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 2.7},
#      {'fuel': 'wind', 'perc': 25.2}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 119, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.2},
#      {'fuel': 'coal', 'perc': 1.8},
#      {'fuel': 'imports', 'perc': 22.3},
#      {'fuel': 'gas', 'perc': 23.7},
#      {'fuel': 'nuclear', 'perc': 3.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0.6},
#      {'fuel': 'wind', 'perc': 45.5}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 43, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 26.5},
#      {'fuel': 'gas', 'perc': 8.4},
#      {'fuel': 'nuclear', 'perc': 10.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 53.9}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 73, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 44.5},
#      {'fuel': 'gas', 'perc': 15.5},
#      {'fuel': 'nuclear', 'perc': 0.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 38.6}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 69, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.5},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 9.3},
#      {'fuel': 'gas', 'perc': 12.6},
#      {'fuel': 'nuclear', 'perc': 17.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 54.1}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 20, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4.5},
#      {'fuel': 'nuclear', 'perc': 33.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 14.1},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 46}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 75, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 19},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.9},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 78.1}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 64, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 7.7},
#      {'fuel': 'gas', 'perc': 12},
#      {'fuel': 'nuclear', 'perc': 18.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 54.6}]}]},
#  {'from': '2024-01-01T00:30Z',
#   'to': '2024-01-01T01:00Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 1, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.3},
#      {'fuel': 'nuclear', 'perc': 3.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 44},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 51.9}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 22, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4.5},
#      {'fuel': 'nuclear', 'perc': 49.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 42.7}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 3, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 39.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 58.9}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 17, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 9.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 1.5},
#      {'fuel': 'nuclear', 'perc': 74.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 14.4}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 81, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 24.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 13.3},
#      {'fuel': 'nuclear', 'perc': 0.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 62}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 30, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 7.6},
#      {'fuel': 'nuclear', 'perc': 12.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 79.3}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 96, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 0.1},
#      {'fuel': 'gas', 'perc': 24},
#      {'fuel': 'nuclear', 'perc': 1.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 74.3}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 50, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.3},
#      {'fuel': 'coal', 'perc': 1.7},
#      {'fuel': 'imports', 'perc': 1.4},
#      {'fuel': 'gas', 'perc': 7.8},
#      {'fuel': 'nuclear', 'perc': 20.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 66.5}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 126, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.2},
#      {'fuel': 'coal', 'perc': 5.6},
#      {'fuel': 'imports', 'perc': 3.1},
#      {'fuel': 'gas', 'perc': 16.3},
#      {'fuel': 'nuclear', 'perc': 3.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.9}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 22, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.4},
#      {'fuel': 'gas', 'perc': 3.4},
#      {'fuel': 'nuclear', 'perc': 19.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.8}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 270, 'index': 'very high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0.2},
#      {'fuel': 'imports', 'perc': 4.3},
#      {'fuel': 'gas', 'perc': 67.6},
#      {'fuel': 'nuclear', 'perc': 0.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 27.1}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 113, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.7},
#      {'fuel': 'coal', 'perc': 1.8},
#      {'fuel': 'imports', 'perc': 27.3},
#      {'fuel': 'gas', 'perc': 22.2},
#      {'fuel': 'nuclear', 'perc': 4.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 42}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 41, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 29.8},
#      {'fuel': 'gas', 'perc': 7.9},
#      {'fuel': 'nuclear', 'perc': 11.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 49.9}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 63, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 50.2},
#      {'fuel': 'gas', 'perc': 13.1},
#      {'fuel': 'nuclear', 'perc': 1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 34.6}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 67, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 10.6},
#      {'fuel': 'gas', 'perc': 12.2},
#      {'fuel': 'nuclear', 'perc': 17.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 53.6}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 18, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.9},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4},
#      {'fuel': 'nuclear', 'perc': 31.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 13.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 49.6}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 74, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 18.8},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 78.5}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 62, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.8},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 8.8},
#      {'fuel': 'gas', 'perc': 11.7},
#      {'fuel': 'nuclear', 'perc': 18.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 54.7}]}]},
#  {'from': '2024-01-01T01:00Z',
#   'to': '2024-01-01T01:30Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 1, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.2},
#      {'fuel': 'nuclear', 'perc': 1.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 49.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 48.9}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 19, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.7},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4.1},
#      {'fuel': 'nuclear', 'perc': 46.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 46.7}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 3, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.5},
#      {'fuel': 'nuclear', 'perc': 39.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 59.2}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 14, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 8.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 1.1},
#      {'fuel': 'nuclear', 'perc': 76},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 14.6}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 79, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 24.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 12.6},
#      {'fuel': 'nuclear', 'perc': 2.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 61}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 29, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 7.2},
#      {'fuel': 'nuclear', 'perc': 13.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 78.9}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 95, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 0.1},
#      {'fuel': 'gas', 'perc': 23.7},
#      {'fuel': 'nuclear', 'perc': 0.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 74.9}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 46, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.4},
#      {'fuel': 'coal', 'perc': 1.5},
#      {'fuel': 'imports', 'perc': 0.8},
#      {'fuel': 'gas', 'perc': 7.4},
#      {'fuel': 'nuclear', 'perc': 21.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 66.7}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 129, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.9},
#      {'fuel': 'coal', 'perc': 5.6},
#      {'fuel': 'imports', 'perc': 2.8},
#      {'fuel': 'gas', 'perc': 16.8},
#      {'fuel': 'nuclear', 'perc': 3.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.6}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 22, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.3},
#      {'fuel': 'gas', 'perc': 3.5},
#      {'fuel': 'nuclear', 'perc': 19.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 65}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 263, 'index': 'high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#      {'fuel': 'coal', 'perc': 0.3},
#      {'fuel': 'imports', 'perc': 5},
#      {'fuel': 'gas', 'perc': 65.7},
#      {'fuel': 'nuclear', 'perc': 0.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 27.8}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 118, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2},
#      {'fuel': 'coal', 'perc': 2.1},
#      {'fuel': 'imports', 'perc': 25.2},
#      {'fuel': 'gas', 'perc': 22.8},
#      {'fuel': 'nuclear', 'perc': 6.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 41.1}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 42, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 28.7},
#      {'fuel': 'gas', 'perc': 8.2},
#      {'fuel': 'nuclear', 'perc': 13.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 49.2}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 66, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 48.7},
#      {'fuel': 'gas', 'perc': 14},
#      {'fuel': 'nuclear', 'perc': 2.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 33.6}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 66, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 10.2},
#      {'fuel': 'gas', 'perc': 12.1},
#      {'fuel': 'nuclear', 'perc': 17.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 53.7}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 16, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.7},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 3.6},
#      {'fuel': 'nuclear', 'perc': 29.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 14.9},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 50.4}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 78, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 19.8},
#      {'fuel': 'nuclear', 'perc': 0.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 3.3},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 76.7}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 62, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.8},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 8.4},
#      {'fuel': 'gas', 'perc': 11.6},
#      {'fuel': 'nuclear', 'perc': 18.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 54.7}]}]},
#  {'from': '2024-01-01T01:30Z',
#   'to': '2024-01-01T02:00Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 0, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.1},
#      {'fuel': 'nuclear', 'perc': 1.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 51.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 47.1}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 20, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 4.3},
#      {'fuel': 'nuclear', 'perc': 45.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 47.6}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 2, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.5},
#      {'fuel': 'nuclear', 'perc': 41.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 57.5}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 11, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.9},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 78.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 14}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 83, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 23.9},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 13.8},
#      {'fuel': 'nuclear', 'perc': 2.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 59.5}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 32, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 8},
#      {'fuel': 'nuclear', 'perc': 13.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.3},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 77.5}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 114, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 28.6},
#      {'fuel': 'nuclear', 'perc': 0.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 70.5}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 46, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.4},
#      {'fuel': 'coal', 'perc': 1.4},
#      {'fuel': 'imports', 'perc': 0.2},
#      {'fuel': 'gas', 'perc': 7.7},
#      {'fuel': 'nuclear', 'perc': 22.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 65.6}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 145, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 9.2},
#      {'fuel': 'coal', 'perc': 5.8},
#      {'fuel': 'imports', 'perc': 1},
#      {'fuel': 'gas', 'perc': 20},
#      {'fuel': 'nuclear', 'perc': 3.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 60.6}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 24, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.2},
#      {'fuel': 'gas', 'perc': 4},
#      {'fuel': 'nuclear', 'perc': 19.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.3}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 294, 'index': 'very high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.4},
#      {'fuel': 'coal', 'perc': 0.3},
#      {'fuel': 'imports', 'perc': 0.8},
#      {'fuel': 'gas', 'perc': 73.7},
#      {'fuel': 'nuclear', 'perc': 0.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 24.1}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 134, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.8},
#      {'fuel': 'coal', 'perc': 2.2},
#      {'fuel': 'imports', 'perc': 7.9},
#      {'fuel': 'gas', 'perc': 26.9},
#      {'fuel': 'nuclear', 'perc': 6.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 52.2}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 46, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 16.1},
#      {'fuel': 'gas', 'perc': 9.6},
#      {'fuel': 'nuclear', 'perc': 13.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.5},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 60.4}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 86, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 23.3},
#      {'fuel': 'gas', 'perc': 19.8},
#      {'fuel': 'nuclear', 'perc': 3.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 52.5}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 75, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.7},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 2.8},
#      {'fuel': 'gas', 'perc': 14.7},
#      {'fuel': 'nuclear', 'perc': 18.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.9},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 57.1}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 15, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.5},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 3.3},
#      {'fuel': 'nuclear', 'perc': 29.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 16.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 49.6}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 85, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 21.6},
#      {'fuel': 'nuclear', 'perc': 0.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 3.8},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 74}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 69, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.1},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 2.3},
#      {'fuel': 'gas', 'perc': 13.8},
#      {'fuel': 'nuclear', 'perc': 18.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 2.8},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 57.3}]}]},
#  {'from': '2024-01-01T02:00Z',
#   'to': '2024-01-01T02:30Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 1, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.1},
#      {'fuel': 'nuclear', 'perc': 1.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 53.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 45}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 18, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 3.7},
#      {'fuel': 'nuclear', 'perc': 44.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.3},
#      {'fuel': 'wind', 'perc': 48.9}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 3, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 42.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 56.8}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 10, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 6.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0.6},
#      {'fuel': 'nuclear', 'perc': 78.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 14.8}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 77, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 23.5},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 12.3},
#      {'fuel': 'nuclear', 'perc': 4.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 59.7}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 28, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 7.1},
#      {'fuel': 'nuclear', 'perc': 14.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.7},
#      {'fuel': 'solar', 'perc': 0.3},
#      {'fuel': 'wind', 'perc': 76.2}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 120, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 30.2},
#      {'fuel': 'nuclear', 'perc': 0.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0.4},
# ...
#      {'fuel': 'imports', 'perc': 11.5},
#      {'fuel': 'gas', 'perc': 0.5},
#      {'fuel': 'nuclear', 'perc': 64.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.9},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 12.3}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 92, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 21.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0.4},
#      {'fuel': 'gas', 'perc': 17},
#      {'fuel': 'nuclear', 'perc': 4.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 56.7}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 36, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0.3},
#      {'fuel': 'gas', 'perc': 8.9},
#      {'fuel': 'nuclear', 'perc': 22.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 3.6},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 63.7}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 106, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.8},
#      {'fuel': 'coal', 'perc': 0.6},
#      {'fuel': 'imports', 'perc': 1.8},
#      {'fuel': 'gas', 'perc': 25.1},
#      {'fuel': 'nuclear', 'perc': 7.1},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.3},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.3}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 68, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.4},
#      {'fuel': 'coal', 'perc': 1.9},
#      {'fuel': 'imports', 'perc': 5.8},
#      {'fuel': 'gas', 'perc': 11.4},
#      {'fuel': 'nuclear', 'perc': 25.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 51.4}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 135, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.2},
#      {'fuel': 'coal', 'perc': 5.6},
#      {'fuel': 'imports', 'perc': 3.8},
#      {'fuel': 'gas', 'perc': 18.8},
#      {'fuel': 'nuclear', 'perc': 7.3},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 60.3}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 29, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 11.1},
#      {'fuel': 'gas', 'perc': 4.3},
#      {'fuel': 'nuclear', 'perc': 19.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.8}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 260, 'index': 'high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.2},
#      {'fuel': 'coal', 'perc': 0.2},
#      {'fuel': 'imports', 'perc': 8.4},
#      {'fuel': 'gas', 'perc': 64.9},
#      {'fuel': 'nuclear', 'perc': 0.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0.1},
#      {'fuel': 'wind', 'perc': 25.2}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 122, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.7},
#      {'fuel': 'coal', 'perc': 1.2},
#      {'fuel': 'imports', 'perc': 38.3},
#      {'fuel': 'gas', 'perc': 25.7},
#      {'fuel': 'nuclear', 'perc': 3.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 30.3}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 49, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 40.2},
#      {'fuel': 'gas', 'perc': 9.2},
#      {'fuel': 'nuclear', 'perc': 8.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 41}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 63, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 60.6},
#      {'fuel': 'gas', 'perc': 12.7},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 25.5}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 78, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.9},
#      {'fuel': 'coal', 'perc': 1.1},
#      {'fuel': 'imports', 'perc': 15.3},
#      {'fuel': 'gas', 'perc': 14.7},
#      {'fuel': 'nuclear', 'perc': 17.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 46.7}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 10, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.7},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 2},
#      {'fuel': 'nuclear', 'perc': 23.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 9},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 63.4}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 41, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.5},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 10.3},
#      {'fuel': 'nuclear', 'perc': 7.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 4.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 77.5}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 68, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.4},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 12.5},
#      {'fuel': 'gas', 'perc': 12.9},
#      {'fuel': 'nuclear', 'perc': 17.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.9},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 50.7}]}]},
#  {'from': '2024-01-02T23:30Z',
#   'to': '2024-01-03T00:00Z',
#   'regions': [{'regionid': 1,
#     'dnoregion': 'Scottish Hydro Electric Power Distribution',
#     'shortname': 'North Scotland',
#     'intensity': {'forecast': 0, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 0},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 14.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 85.3}]},
#    {'regionid': 2,
#     'dnoregion': 'SP Distribution',
#     'shortname': 'South Scotland',
#     'intensity': {'forecast': 14, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.3},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 2.8},
#      {'fuel': 'nuclear', 'perc': 33.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 5.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 55.4}]},
#    {'regionid': 3,
#     'dnoregion': 'Electricity North West',
#     'shortname': 'North West England',
#     'intensity': {'forecast': 9, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.7},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 3},
#      {'fuel': 'gas', 'perc': 1.5},
#      {'fuel': 'nuclear', 'perc': 43.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.2},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 48}]},
#    {'regionid': 4,
#     'dnoregion': 'NPG North East',
#     'shortname': 'North East England',
#     'intensity': {'forecast': 12, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 7.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 18.8},
#      {'fuel': 'gas', 'perc': 0.4},
#      {'fuel': 'nuclear', 'perc': 61.6},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 10.5}]},
#    {'regionid': 5,
#     'dnoregion': 'NPG Yorkshire',
#     'shortname': 'Yorkshire',
#     'intensity': {'forecast': 88, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 22.4},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 1.1},
#      {'fuel': 'gas', 'perc': 15.4},
#      {'fuel': 'nuclear', 'perc': 1.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 59.1}]},
#    {'regionid': 6,
#     'dnoregion': 'SP Manweb',
#     'shortname': 'North Wales & Merseyside',
#     'intensity': {'forecast': 49, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 1.2},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0.8},
#      {'fuel': 'gas', 'perc': 12.2},
#      {'fuel': 'nuclear', 'perc': 21.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 4.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 60.2}]},
#    {'regionid': 7,
#     'dnoregion': 'WPD South Wales',
#     'shortname': 'South Wales',
#     'intensity': {'forecast': 92, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.9},
#      {'fuel': 'coal', 'perc': 0.5},
#      {'fuel': 'imports', 'perc': 2.6},
#      {'fuel': 'gas', 'perc': 21.4},
#      {'fuel': 'nuclear', 'perc': 6.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 67.3}]},
#    {'regionid': 8,
#     'dnoregion': 'WPD West Midlands',
#     'shortname': 'West Midlands',
#     'intensity': {'forecast': 63, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 2.7},
#      {'fuel': 'coal', 'perc': 1.7},
#      {'fuel': 'imports', 'perc': 7.6},
#      {'fuel': 'gas', 'perc': 10.4},
#      {'fuel': 'nuclear', 'perc': 21.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 54.6}]},
#    {'regionid': 9,
#     'dnoregion': 'WPD East Midlands',
#     'shortname': 'East Midlands',
#     'intensity': {'forecast': 102, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.4},
#      {'fuel': 'coal', 'perc': 4.5},
#      {'fuel': 'imports', 'perc': 5.1},
#      {'fuel': 'gas', 'perc': 12.6},
#      {'fuel': 'nuclear', 'perc': 9.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 64.1}]},
#    {'regionid': 10,
#     'dnoregion': 'UKPN East',
#     'shortname': 'East England',
#     'intensity': {'forecast': 33, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 12.1},
#      {'fuel': 'gas', 'perc': 4.9},
#      {'fuel': 'nuclear', 'perc': 20.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 62.2}]},
#    {'regionid': 11,
#     'dnoregion': 'WPD South West',
#     'shortname': 'South West England',
#     'intensity': {'forecast': 282, 'index': 'very high'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0.1},
#      {'fuel': 'imports', 'perc': 5.6},
#      {'fuel': 'gas', 'perc': 70.9},
#      {'fuel': 'nuclear', 'perc': 0.7},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 22.5}]},
#    {'regionid': 12,
#     'dnoregion': 'SSE South',
#     'shortname': 'South England',
#     'intensity': {'forecast': 112, 'index': 'moderate'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0.6},
#      {'fuel': 'imports', 'perc': 40.7},
#      {'fuel': 'gas', 'perc': 24.4},
#      {'fuel': 'nuclear', 'perc': 2.8},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.7},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 30.3}]},
#    {'regionid': 13,
#     'dnoregion': 'UKPN London',
#     'shortname': 'London',
#     'intensity': {'forecast': 56, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 40.9},
#      {'fuel': 'gas', 'perc': 10.8},
#      {'fuel': 'nuclear', 'perc': 7.5},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 40.2}]},
#    {'regionid': 14,
#     'dnoregion': 'UKPN South East',
#     'shortname': 'South East England',
#     'intensity': {'forecast': 70, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 59.9},
#      {'fuel': 'gas', 'perc': 14.6},
#      {'fuel': 'nuclear', 'perc': 0},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 24.5}]},
#    {'regionid': 15,
#     'dnoregion': 'England',
#     'shortname': 'England',
#     'intensity': {'forecast': 74, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 4.2},
#      {'fuel': 'coal', 'perc': 0.9},
#      {'fuel': 'imports', 'perc': 15.6},
#      {'fuel': 'gas', 'perc': 14},
#      {'fuel': 'nuclear', 'perc': 19.4},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 0.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 45.3}]},
#    {'regionid': 16,
#     'dnoregion': 'Scotland',
#     'shortname': 'Scotland',
#     'intensity': {'forecast': 8, 'index': 'very low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.6},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 1.8},
#      {'fuel': 'nuclear', 'perc': 15.2},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 9.6},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 72.7}]},
#    {'regionid': 17,
#     'dnoregion': 'Wales',
#     'shortname': 'Wales',
#     'intensity': {'forecast': 52, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 0.1},
#      {'fuel': 'coal', 'perc': 0},
#      {'fuel': 'imports', 'perc': 0},
#      {'fuel': 'gas', 'perc': 13.2},
#      {'fuel': 'nuclear', 'perc': 3.9},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 4},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 78.7}]},
#    {'regionid': 18,
#     'dnoregion': 'GB',
#     'shortname': 'GB',
#     'intensity': {'forecast': 65, 'index': 'low'},
#     'generationmix': [{'fuel': 'biomass', 'perc': 3.5},
#      {'fuel': 'coal', 'perc': 0.7},
#      {'fuel': 'imports', 'perc': 12.9},
#      {'fuel': 'gas', 'perc': 12.6},
#      {'fuel': 'nuclear', 'perc': 18},
#      {'fuel': 'other', 'perc': 0},
#      {'fuel': 'hydro', 'perc': 1.8},
#      {'fuel': 'solar', 'perc': 0},
#      {'fuel': 'wind', 'perc': 50.5}]}]}]

# %%
extracted_data = []
for entry in int_date_range:
    time = datetime.strptime(entry['from'], '%Y-%m-%dT%H:%MZ')
    date_rec = time.strftime('%Y-%m-%d')
    time_rec = time.strftime('%H:%M')
    day = time.strftime('%A')
    month = time.strftime('%B')
    for region in entry['regions']:
        dnoregion = region['dnoregion']
        regionid = region['regionid']
        intensity_forecast = region['intensity']['forecast']
        intensity_index = region['intensity']['index']
        # generationmix = region['generationmix']
        generation_mix_data = {}
        for fuel_data in region['generationmix']:
            fuel_type = fuel_data['fuel']
            percentage = fuel_data['perc']
            generation_mix_data[fuel_type] = percentage
        extracted_data.append({
            'date': date_rec,
            'from': time_rec,
            'day_recorded': day,
            'month_recorded': month,
            'dnoregion': dnoregion,
            'regionid': regionid,
            'intensity_forecast': intensity_forecast,
            'intensity_index': intensity_index,
            **generation_mix_data
        })

len(extracted_data)
pp(extracted_data)
# Out:
# [{'biomass': 0.6,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '23:30',
#   'gas': 0.8,
#   'hydro': 44.4,
#   'imports': 0,
#   'intensity_forecast': 4,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 6.8,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 47.4},
#  {'biomass': 3.7,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'SP Distribution',
#   'from': '23:30',
#   'gas': 4.8,
#   'hydro': 0,
#   'imports': 0.1,
#   'intensity_forecast': 24,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 58.6,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 32.7},
#  {'biomass': 0.9,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'Electricity North West',
#   'from': '23:30',
#   'gas': 0.8,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 4,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 41.3,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 57.1},
#  {'biomass': 9.4,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'NPG North East',
#   'from': '23:30',
#   'gas': 1.4,
#   'hydro': 0,
#   'imports': 2.3,
#   'intensity_forecast': 17,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 73.8,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 13.1},
#  {'biomass': 25,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '23:30',
#   'gas': 13.4,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 83,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 61.6},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'SP Manweb',
#   'from': '23:30',
#   'gas': 7.4,
#   'hydro': 1.3,
#   'imports': 0,
#   'intensity_forecast': 30,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 11.7,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 79.2},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'WPD South Wales',
#   'from': '23:30',
#   'gas': 21.7,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 86,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 0.9,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 77.3},
#  {'biomass': 2.5,
#   'coal': 1.9,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '23:30',
#   'gas': 7.7,
#   'hydro': 0.4,
#   'imports': 1.1,
#   'intensity_forecast': 52,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 20.8,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 65.8},
#  {'biomass': 6.3,
#   'coal': 6,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '23:30',
#   'gas': 15.8,
#   'hydro': 0,
#   'imports': 3,
#   'intensity_forecast': 128,
#   'intensity_index': 'moderate',
#   'month_recorded': 'December',
#   'nuclear': 4.8,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 64.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'UKPN East',
#   'from': '23:30',
#   'gas': 2.6,
#   'hydro': 0,
#   'imports': 12.5,
#   'intensity_forecast': 19,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 20.5,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 64.4},
#  {'biomass': 0.1,
#   'coal': 0.2,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'WPD South West',
#   'from': '23:30',
#   'gas': 70.9,
#   'hydro': 0.1,
#   'imports': 1.4,
#   'intensity_forecast': 281,
#   'intensity_index': 'very high',
#   'month_recorded': 'December',
#   'nuclear': 0.4,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 27},
#  {'biomass': 2,
#   'coal': 2,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'SSE South',
#   'from': '23:30',
#   'gas': 22.8,
#   'hydro': 0.7,
#   'imports': 23.5,
#   'intensity_forecast': 118,
#   'intensity_index': 'moderate',
#   'month_recorded': 'December',
#   'nuclear': 3.6,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 45.3},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'UKPN London',
#   'from': '23:30',
#   'gas': 8.5,
#   'hydro': 0.6,
#   'imports': 26.4,
#   'intensity_forecast': 43,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 11.2,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 53.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'UKPN South East',
#   'from': '23:30',
#   'gas': 16.1,
#   'hydro': 1.4,
#   'imports': 44.2,
#   'intensity_forecast': 75,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 0.3,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 37.9},
#  {'biomass': 4.7,
#   'coal': 1.1,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'England',
#   'from': '23:30',
#   'gas': 12.2,
#   'hydro': 0.2,
#   'imports': 10.1,
#   'intensity_forecast': 69,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 19.1,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 52.6},
#  {'biomass': 1.8,
#   'coal': 0.1,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'Scotland',
#   'from': '23:30',
#   'gas': 5.7,
#   'hydro': 16.8,
#   'imports': 0.7,
#   'intensity_forecast': 25,
#   'intensity_index': 'very low',
#   'month_recorded': 'December',
#   'nuclear': 29.4,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 45.6},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'Wales',
#   'from': '23:30',
#   'gas': 15,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 59,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 85},
#  {'biomass': 4,
#   'coal': 0.9,
#   'date': '2023-12-31',
#   'day_recorded': 'Sunday',
#   'dnoregion': 'GB',
#   'from': '23:30',
#   'gas': 11.6,
#   'hydro': 2.2,
#   'imports': 8.2,
#   'intensity_forecast': 63,
#   'intensity_index': 'low',
#   'month_recorded': 'December',
#   'nuclear': 19,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 53.9},
#  {'biomass': 0.4,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '00:00',
#   'gas': 0.6,
#   'hydro': 44.6,
#   'imports': 0,
#   'intensity_forecast': 3,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 4.5,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 50},
#  {'biomass': 3.4,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '00:00',
#   'gas': 4.8,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 23,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 54.6,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 37.2},
#  {'biomass': 0.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '00:00',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 3,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 40.9,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0.1,
#   'wind': 57.9},
#  {'biomass': 9.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '00:00',
#   'gas': 1.2,
#   'hydro': 0,
#   'imports': 0.7,
#   'intensity_forecast': 16,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 76.6,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 12.3},
#  {'biomass': 24.8,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '00:00',
#   'gas': 13.4,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 83,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 61.8},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '00:00',
#   'gas': 7.5,
#   'hydro': 0.6,
#   'imports': 0,
#   'intensity_forecast': 30,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 12.4,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 79.2},
#  {'biomass': 0.1,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '00:00',
#   'gas': 23.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 94,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 1.6,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0.5,
#   'wind': 73.9},
#  {'biomass': 2.3,
#   'coal': 1.8,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '00:00',
#   'gas': 7.7,
#   'hydro': 0.2,
#   'imports': 0.8,
#   'intensity_forecast': 51,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 20.9,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0.4,
#   'wind': 65.8},
#  {'biomass': 6.6,
#   'coal': 5.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '00:00',
#   'gas': 17.2,
#   'hydro': 0,
#   'imports': 2.6,
#   'intensity_forecast': 133,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 4.7,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0.1,
#   'wind': 63},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '00:00',
#   'gas': 2.7,
#   'hydro': 0,
#   'imports': 12.2,
#   'intensity_forecast': 19,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 20,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0.2,
#   'wind': 64.8},
#  {'biomass': 0.2,
#   'coal': 0.2,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '00:00',
#   'gas': 69.5,
#   'hydro': 0.1,
#   'imports': 1.7,
#   'intensity_forecast': 277,
#   'intensity_index': 'very high',
#   'month_recorded': 'January',
#   'nuclear': 0.4,
#   'other': 0,
#   'regionid': 11,
#   'solar': 2.7,
#   'wind': 25.2},
#  {'biomass': 2.2,
#   'coal': 1.8,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '00:00',
#   'gas': 23.7,
#   'hydro': 0.6,
#   'imports': 22.3,
#   'intensity_forecast': 119,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.3,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0.6,
#   'wind': 45.5},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '00:00',
#   'gas': 8.4,
#   'hydro': 0.5,
#   'imports': 26.5,
#   'intensity_forecast': 43,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 10.6,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0.1,
#   'wind': 53.9},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '00:00',
#   'gas': 15.5,
#   'hydro': 1.2,
#   'imports': 44.5,
#   'intensity_forecast': 73,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.2,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 38.6},
#  {'biomass': 4.5,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '00:00',
#   'gas': 12.6,
#   'hydro': 0.4,
#   'imports': 9.3,
#   'intensity_forecast': 69,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.9,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 54.1},
#  {'biomass': 2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '00:00',
#   'gas': 4.5,
#   'hydro': 14.1,
#   'imports': 0,
#   'intensity_forecast': 20,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 33.3,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0.1,
#   'wind': 46},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '00:00',
#   'gas': 19,
#   'hydro': 2.9,
#   'imports': 0,
#   'intensity_forecast': 75,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 78.1},
#  {'biomass': 4,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '00:00',
#   'gas': 12,
#   'hydro': 2.1,
#   'imports': 7.7,
#   'intensity_forecast': 64,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.6,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 54.6},
#  {'biomass': 0.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '00:30',
#   'gas': 0.3,
#   'hydro': 44,
#   'imports': 0,
#   'intensity_forecast': 1,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 3.6,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 51.9},
#  {'biomass': 3.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '00:30',
#   'gas': 4.5,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 22,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 49.7,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 42.7},
#  {'biomass': 0.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '00:30',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 3,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 39.9,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 58.9},
#  {'biomass': 9.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '00:30',
#   'gas': 1.5,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 17,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 74.6,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 14.4},
#  {'biomass': 24.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '00:30',
#   'gas': 13.3,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 81,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.6,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 62},
#  {'biomass': 0.4,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '00:30',
#   'gas': 7.6,
#   'hydro': 0.5,
#   'imports': 0,
#   'intensity_forecast': 30,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 12.4,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 79.3},
#  {'biomass': 0.2,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '00:30',
#   'gas': 24,
#   'hydro': 0,
#   'imports': 0.1,
#   'intensity_forecast': 96,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 1.3,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 74.3},
#  {'biomass': 2.3,
#   'coal': 1.7,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '00:30',
#   'gas': 7.8,
#   'hydro': 0.1,
#   'imports': 1.4,
#   'intensity_forecast': 50,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 20.2,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 66.5},
#  {'biomass': 6.2,
#   'coal': 5.6,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '00:30',
#   'gas': 16.3,
#   'hydro': 0,
#   'imports': 3.1,
#   'intensity_forecast': 126,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.9,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 64.9},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '00:30',
#   'gas': 3.4,
#   'hydro': 0,
#   'imports': 12.4,
#   'intensity_forecast': 22,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.4,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 64.8},
#  {'biomass': 0.3,
#   'coal': 0.2,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '00:30',
#   'gas': 67.6,
#   'hydro': 0.1,
#   'imports': 4.3,
#   'intensity_forecast': 270,
#   'intensity_index': 'very high',
#   'month_recorded': 'January',
#   'nuclear': 0.5,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 27.1},
#  {'biomass': 1.7,
#   'coal': 1.8,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '00:30',
#   'gas': 22.2,
#   'hydro': 0.5,
#   'imports': 27.3,
#   'intensity_forecast': 113,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 4.4,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 42},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '00:30',
#   'gas': 7.9,
#   'hydro': 0.5,
#   'imports': 29.8,
#   'intensity_forecast': 41,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 11.9,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 49.9},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '00:30',
#   'gas': 13.1,
#   'hydro': 1.1,
#   'imports': 50.2,
#   'intensity_forecast': 63,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 1,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 34.6},
#  {'biomass': 4.4,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '00:30',
#   'gas': 12.2,
#   'hydro': 0.5,
#   'imports': 10.6,
#   'intensity_forecast': 67,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.6,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 53.6},
#  {'biomass': 1.9,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '00:30',
#   'gas': 4,
#   'hydro': 13.4,
#   'imports': 0,
#   'intensity_forecast': 18,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 31.1,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 49.6},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '00:30',
#   'gas': 18.8,
#   'hydro': 2.7,
#   'imports': 0,
#   'intensity_forecast': 74,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 78.5},
#  {'biomass': 3.8,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '00:30',
#   'gas': 11.7,
#   'hydro': 2.1,
#   'imports': 8.8,
#   'intensity_forecast': 62,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.1,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 54.7},
#  {'biomass': 0.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '01:00',
#   'gas': 0.2,
#   'hydro': 49.2,
#   'imports': 0,
#   'intensity_forecast': 1,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 1.5,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 48.9},
#  {'biomass': 2.7,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '01:00',
#   'gas': 4.1,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 19,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 46.4,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 46.7},
#  {'biomass': 0.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '01:00',
#   'gas': 0.5,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 3,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 39.6,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 59.2},
#  {'biomass': 8.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '01:00',
#   'gas': 1.1,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 14,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 76,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0.1,
#   'wind': 14.6},
#  {'biomass': 24.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '01:00',
#   'gas': 12.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 79,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 2.2,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 61},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '01:00',
#   'gas': 7.2,
#   'hydro': 0.2,
#   'imports': 0,
#   'intensity_forecast': 29,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 13.4,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 78.9},
#  {'biomass': 0.3,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '01:00',
#   'gas': 23.7,
#   'hydro': 0,
#   'imports': 0.1,
#   'intensity_forecast': 95,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.9,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 74.9},
#  {'biomass': 2.4,
#   'coal': 1.5,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '01:00',
#   'gas': 7.4,
#   'hydro': 0.1,
#   'imports': 0.8,
#   'intensity_forecast': 46,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 21.1,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0.1,
#   'wind': 66.7},
#  {'biomass': 6.9,
#   'coal': 5.6,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '01:00',
#   'gas': 16.8,
#   'hydro': 0,
#   'imports': 2.8,
#   'intensity_forecast': 129,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.3,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 64.6},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '01:00',
#   'gas': 3.5,
#   'hydro': 0,
#   'imports': 12.3,
#   'intensity_forecast': 22,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.2,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 65},
#  {'biomass': 0.4,
#   'coal': 0.3,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '01:00',
#   'gas': 65.7,
#   'hydro': 0.1,
#   'imports': 5,
#   'intensity_forecast': 263,
#   'intensity_index': 'high',
#   'month_recorded': 'January',
#   'nuclear': 0.7,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 27.8},
#  {'biomass': 2,
#   'coal': 2.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '01:00',
#   'gas': 22.8,
#   'hydro': 0.4,
#   'imports': 25.2,
#   'intensity_forecast': 118,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 6.4,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 41.1},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '01:00',
#   'gas': 8.2,
#   'hydro': 0.4,
#   'imports': 28.7,
#   'intensity_forecast': 42,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 13.4,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 49.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '01:00',
#   'gas': 14,
#   'hydro': 1.1,
#   'imports': 48.7,
#   'intensity_forecast': 66,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 2.7,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 33.6},
#  {'biomass': 4.4,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '01:00',
#   'gas': 12.1,
#   'hydro': 0.7,
#   'imports': 10.2,
#   'intensity_forecast': 66,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.9,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 53.7},
#  {'biomass': 1.7,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '01:00',
#   'gas': 3.6,
#   'hydro': 14.9,
#   'imports': 0,
#   'intensity_forecast': 16,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 29.4,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 50.4},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '01:00',
#   'gas': 19.8,
#   'hydro': 3.3,
#   'imports': 0,
#   'intensity_forecast': 78,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.2,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0.1,
#   'wind': 76.7},
#  {'biomass': 3.8,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '01:00',
#   'gas': 11.6,
#   'hydro': 2.4,
#   'imports': 8.4,
#   'intensity_forecast': 62,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.1,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 54.7},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '01:30',
#   'gas': 0.1,
#   'hydro': 51.4,
#   'imports': 0,
#   'intensity_forecast': 0,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 1.3,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 47.1},
#  {'biomass': 2.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '01:30',
#   'gas': 4.3,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 20,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 45.6,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 47.6},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '01:30',
#   'gas': 0.5,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 2,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 41.8,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 57.5},
#  {'biomass': 6.9,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '01:30',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 11,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 78.5,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 14},
#  {'biomass': 23.9,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '01:30',
#   'gas': 13.8,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 83,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 2.7,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 59.5},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '01:30',
#   'gas': 8,
#   'hydro': 0.3,
#   'imports': 0,
#   'intensity_forecast': 32,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 13.8,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 77.5},
#  {'biomass': 0,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '01:30',
#   'gas': 28.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 114,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 0.7,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 70.5},
#  {'biomass': 2.4,
#   'coal': 1.4,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '01:30',
#   'gas': 7.7,
#   'hydro': 0.1,
#   'imports': 0.2,
#   'intensity_forecast': 46,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 22.6,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 65.6},
#  {'biomass': 9.2,
#   'coal': 5.8,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '01:30',
#   'gas': 20,
#   'hydro': 0,
#   'imports': 1,
#   'intensity_forecast': 145,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.3,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 60.6},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '01:30',
#   'gas': 4,
#   'hydro': 0,
#   'imports': 12.2,
#   'intensity_forecast': 24,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.5,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 64.3},
#  {'biomass': 0.4,
#   'coal': 0.3,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '01:30',
#   'gas': 73.7,
#   'hydro': 0.1,
#   'imports': 0.8,
#   'intensity_forecast': 294,
#   'intensity_index': 'very high',
#   'month_recorded': 'January',
#   'nuclear': 0.7,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 24.1},
#  {'biomass': 3.8,
#   'coal': 2.2,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '01:30',
#   'gas': 26.9,
#   'hydro': 0.4,
#   'imports': 7.9,
#   'intensity_forecast': 134,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 6.6,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 52.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '01:30',
#   'gas': 9.6,
#   'hydro': 0.5,
#   'imports': 16.1,
#   'intensity_forecast': 46,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 13.5,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 60.4},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '01:30',
#   'gas': 19.8,
#   'hydro': 1.2,
#   'imports': 23.3,
#   'intensity_forecast': 86,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 3.1,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 52.5},
#  {'biomass': 4.7,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '01:30',
#   'gas': 14.7,
#   'hydro': 0.9,
#   'imports': 2.8,
#   'intensity_forecast': 75,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.7,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 57.1},
#  {'biomass': 1.5,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '01:30',
#   'gas': 3.3,
#   'hydro': 16.2,
#   'imports': 0,
#   'intensity_forecast': 15,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 29.4,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 49.6},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '01:30',
#   'gas': 21.6,
#   'hydro': 3.8,
#   'imports': 0,
#   'intensity_forecast': 85,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.5,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 74},
#  {'biomass': 4.1,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '01:30',
#   'gas': 13.8,
#   'hydro': 2.8,
#   'imports': 2.3,
#   'intensity_forecast': 69,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.8,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 57.3},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '02:00',
#   'gas': 0.1,
#   'hydro': 53.2,
#   'imports': 0,
#   'intensity_forecast': 1,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 1.6,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 45},
#  {'biomass': 2.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '02:00',
#   'gas': 3.7,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 18,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 44.7,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0.3,
#   'wind': 48.9},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '02:00',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 3,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 42.3,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 56.8},
#  {'biomass': 6.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '02:00',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 10,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 78.3,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0.1,
#   'wind': 14.8},
#  {'biomass': 23.5,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '02:00',
#   'gas': 12.3,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 77,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 4.5,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0.1,
#   'wind': 59.7},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '02:00',
#   'gas': 7.1,
#   'hydro': 1.7,
#   'imports': 0,
#   'intensity_forecast': 28,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 14.4,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0.3,
#   'wind': 76.2},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '02:00',
#   'gas': 30.2,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 120,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 0.6,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0.4,
#   'wind': 68.6},
#  {'biomass': 2.2,
#   'coal': 1.2,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '02:00',
#   'gas': 6.5,
#   'hydro': 0.6,
#   'imports': 0.2,
#   'intensity_forecast': 40,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 23.5,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0.6,
#   'wind': 65.2},
#  {'biomass': 10,
#   'coal': 5.8,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '02:00',
#   'gas': 18.3,
#   'hydro': 0,
#   'imports': 0.8,
#   'intensity_forecast': 139,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.3,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0.2,
#   'wind': 61.7},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '02:00',
#   'gas': 3.7,
#   'hydro': 0,
#   'imports': 12.1,
#   'intensity_forecast': 23,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.6,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0.1,
#   'wind': 64.5},
#  {'biomass': 1.2,
#   'coal': 0.7,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '02:00',
#   'gas': 58.9,
#   'hydro': 0.1,
#   'imports': 1.9,
#   'intensity_forecast': 240,
#   'intensity_index': 'high',
#   'month_recorded': 'January',
#   'nuclear': 2.1,
#   'other': 0,
#   'regionid': 11,
#   'solar': 1.1,
#   'wind': 34},
#  {'biomass': 4.1,
#   'coal': 2.3,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '02:00',
#   'gas': 24.4,
#   'hydro': 0.5,
#   'imports': 6.2,
#   'intensity_forecast': 125,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 8,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0.6,
#   'wind': 53.9},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '02:00',
#   'gas': 10.5,
#   'hydro': 0.4,
#   'imports': 14.4,
#   'intensity_forecast': 49,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 14.4,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0.1,
#   'wind': 60.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '02:00',
#   'gas': 23.3,
#   'hydro': 1.3,
#   'imports': 18.8,
#   'intensity_forecast': 98,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 4,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0.2,
#   'wind': 52.5},
#  {'biomass': 4.6,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '02:00',
#   'gas': 13.3,
#   'hydro': 1,
#   'imports': 3.7,
#   'intensity_forecast': 70,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.9,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0.1,
#   'wind': 57.2},
#  {'biomass': 1.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '02:00',
#   'gas': 2.6,
#   'hydro': 17.5,
#   'imports': 0,
#   'intensity_forecast': 12,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 28.6,
#   'other': 0,
#   'regionid': 16,
#   'solar': 1.1,
#   'wind': 48.8},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '02:00',
#   'gas': 22.2,
#   'hydro': 4.4,
#   'imports': 0,
#   'intensity_forecast': 87,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0.6,
#   'other': 0,
#   'regionid': 17,
#   'solar': 1.3,
#   'wind': 71.6},
#  {'biomass': 4,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '02:00',
#   'gas': 12.7,
#   'hydro': 3.1,
#   'imports': 3,
#   'intensity_forecast': 65,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.9,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0.3,
#   'wind': 57.2},
#  {'biomass': 0.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '02:30',
#   'gas': 0.2,
#   'hydro': 47.2,
#   'imports': 0,
#   'intensity_forecast': 1,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 2.5,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 49.9},
#  {'biomass': 2.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '02:30',
#   'gas': 2.4,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 12,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 41,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 54.4},
#  {'biomass': 0.4,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '02:30',
#   'gas': 1.1,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 5,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 41.8,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 56.7},
#  {'biomass': 6.6,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '02:30',
#   'gas': 0.4,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 10,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 76.5,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 16.4},
#  {'biomass': 23.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '02:30',
#   'gas': 15.3,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 88,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 4.2,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 57.3},
#  {'biomass': 0.4,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '02:30',
#   'gas': 6.3,
#   'hydro': 1,
#   'imports': 0,
#   'intensity_forecast': 25,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 13.3,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 79.1},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '02:30',
#   'gas': 28.9,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 114,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 0.2,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 70.9},
#  {'biomass': 2.4,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '02:30',
#   'gas': 9.2,
#   'hydro': 0.4,
#   'imports': 0.1,
#   'intensity_forecast': 49,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 22.3,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 64.6},
#  {'biomass': 9.1,
#   'coal': 5.3,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '02:30',
#   'gas': 27.3,
#   'hydro': 0,
#   'imports': 0.4,
#   'intensity_forecast': 169,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 2.3,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 55.5},
#  {'biomass': 0,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '02:30',
#   'gas': 2.7,
#   'hydro': 0,
#   'imports': 10.4,
#   'intensity_forecast': 18,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 20,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 66.8},
#  {'biomass': 1.2,
#   'coal': 0.6,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South West',
#   'from': '02:30',
#   'gas': 60,
#   'hydro': 0.1,
#   'imports': 2.9,
#   'intensity_forecast': 244,
#   'intensity_index': 'high',
#   'month_recorded': 'January',
#   'nuclear': 1.8,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 33.5},
#  {'biomass': 3.9,
#   'coal': 2.5,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SSE South',
#   'from': '02:30',
#   'gas': 25.5,
#   'hydro': 0.5,
#   'imports': 9.4,
#   'intensity_forecast': 131,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 7.8,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 50.5},
#  {'biomass': 0,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN London',
#   'from': '02:30',
#   'gas': 6,
#   'hydro': 0.5,
#   'imports': 17.8,
#   'intensity_forecast': 31,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 15.2,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 60.4},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN South East',
#   'from': '02:30',
#   'gas': 11.7,
#   'hydro': 1.6,
#   'imports': 30.9,
#   'intensity_forecast': 54,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 4.3,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 51.4},
#  {'biomass': 4.6,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'England',
#   'from': '02:30',
#   'gas': 13.1,
#   'hydro': 1.1,
#   'imports': 4.4,
#   'intensity_forecast': 69,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.7,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 57},
#  {'biomass': 1.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scotland',
#   'from': '02:30',
#   'gas': 2.5,
#   'hydro': 14.4,
#   'imports': 0,
#   'intensity_forecast': 11,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 27.6,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 54.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Wales',
#   'from': '02:30',
#   'gas': 24.8,
#   'hydro': 4.3,
#   'imports': 0,
#   'intensity_forecast': 98,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 1.1,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 69.9},
#  {'biomass': 4,
#   'coal': 0.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'GB',
#   'from': '02:30',
#   'gas': 12.7,
#   'hydro': 2.7,
#   'imports': 3.7,
#   'intensity_forecast': 64,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18.6,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 57.4},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '03:00',
#   'gas': 0.1,
#   'hydro': 45.1,
#   'imports': 0,
#   'intensity_forecast': 0,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 0.4,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 54.3},
#  {'biomass': 2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Distribution',
#   'from': '03:00',
#   'gas': 3.2,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 15,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 36.7,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 58.1},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'Electricity North West',
#   'from': '03:00',
#   'gas': 0.5,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 2,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 40.7,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 58.4},
#  {'biomass': 6.2,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG North East',
#   'from': '03:00',
#   'gas': 0.6,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 10,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 74.1,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0.1,
#   'wind': 19},
#  {'biomass': 23.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '03:00',
#   'gas': 12.3,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 77,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 6,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 58.3},
#  {'biomass': 0.3,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'SP Manweb',
#   'from': '03:00',
#   'gas': 6.7,
#   'hydro': 1.5,
#   'imports': 0,
#   'intensity_forecast': 27,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 14.3,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0.6,
#   'wind': 76.6},
#  {'biomass': 0.1,
#   'coal': 0.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD South Wales',
#   'from': '03:00',
#   'gas': 27.9,
#   'hydro': 0,
#   'imports': 0,
#   'intensity_forecast': 111,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 1.9,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 69.9},
#  {'biomass': 2.4,
#   'coal': 1.1,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '03:00',
#   'gas': 6.3,
#   'hydro': 0.5,
#   'imports': 0.1,
#   'intensity_forecast': 38,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 23.6,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0.3,
#   'wind': 65.6},
#  {'biomass': 10.1,
#   'coal': 5.9,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '03:00',
#   'gas': 17.5,
#   'hydro': 0,
#   'imports': 0.6,
#   'intensity_forecast': 136,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.8,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0.3,
#   'wind': 61.8},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-01',
#   'day_recorded': 'Monday',
#   'dnoregion': 'UKPN East',
#   'from': '03:00',
#   'gas': 3.4,
#   'hydro': 0,
#   'imports': 8.7,
#   'intensity_forecast': 19,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 20.4,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0.2,
# ...
#   'month_recorded': 'January',
#   'nuclear': 7,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 58.5},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN East',
#   'from': '22:30',
#   'gas': 4,
#   'hydro': 0,
#   'imports': 11.7,
#   'intensity_forecast': 28,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.5,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 64.8},
#  {'biomass': 0.1,
#   'coal': 0.2,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD South West',
#   'from': '22:30',
#   'gas': 68.2,
#   'hydro': 0.1,
#   'imports': 8.2,
#   'intensity_forecast': 272,
#   'intensity_index': 'very high',
#   'month_recorded': 'January',
#   'nuclear': 0.5,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 22.7},
#  {'biomass': 0.3,
#   'coal': 0.9,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SSE South',
#   'from': '22:30',
#   'gas': 26.8,
#   'hydro': 0.7,
#   'imports': 39.8,
#   'intensity_forecast': 124,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 28.5},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN London',
#   'from': '22:30',
#   'gas': 9.2,
#   'hydro': 0.7,
#   'imports': 41.6,
#   'intensity_forecast': 49,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 8.7,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 39.8},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN South East',
#   'from': '22:30',
#   'gas': 12.6,
#   'hydro': 1.2,
#   'imports': 60.7,
#   'intensity_forecast': 63,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 25.5},
#  {'biomass': 3.8,
#   'coal': 1.1,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'England',
#   'from': '22:30',
#   'gas': 15.3,
#   'hydro': 0.6,
#   'imports': 15,
#   'intensity_forecast': 81,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.4,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 46.8},
#  {'biomass': 1.9,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Scotland',
#   'from': '22:30',
#   'gas': 2,
#   'hydro': 9.8,
#   'imports': 0,
#   'intensity_forecast': 10,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 24.7,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 61.7},
#  {'biomass': 0.6,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Wales',
#   'from': '22:30',
#   'gas': 9.7,
#   'hydro': 4.5,
#   'imports': 0,
#   'intensity_forecast': 39,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 7.6,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 77.6},
#  {'biomass': 3.4,
#   'coal': 0.9,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'GB',
#   'from': '22:30',
#   'gas': 13.4,
#   'hydro': 1.9,
#   'imports': 12.3,
#   'intensity_forecast': 70,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.6,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 50.5},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '23:00',
#   'gas': 0,
#   'hydro': 16.9,
#   'imports': 0,
#   'intensity_forecast': 0,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 83.1},
#  {'biomass': 2,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SP Distribution',
#   'from': '23:00',
#   'gas': 3.1,
#   'hydro': 6.2,
#   'imports': 0,
#   'intensity_forecast': 15,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 31.3,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 57.4},
#  {'biomass': 2.2,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Electricity North West',
#   'from': '23:00',
#   'gas': 1.4,
#   'hydro': 1,
#   'imports': 1.1,
#   'intensity_forecast': 8,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 47.1,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0.1,
#   'wind': 47},
#  {'biomass': 10,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'NPG North East',
#   'from': '23:00',
#   'gas': 0.5,
#   'hydro': 0.9,
#   'imports': 11.5,
#   'intensity_forecast': 15,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 64.7,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0.1,
#   'wind': 12.3},
#  {'biomass': 21.2,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '23:00',
#   'gas': 17,
#   'hydro': 0.1,
#   'imports': 0.4,
#   'intensity_forecast': 92,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 4.6,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 56.7},
#  {'biomass': 1.1,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SP Manweb',
#   'from': '23:00',
#   'gas': 8.9,
#   'hydro': 3.6,
#   'imports': 0.3,
#   'intensity_forecast': 36,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 22.4,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0.1,
#   'wind': 63.7},
#  {'biomass': 0.8,
#   'coal': 0.6,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD South Wales',
#   'from': '23:00',
#   'gas': 25.1,
#   'hydro': 0.3,
#   'imports': 1.8,
#   'intensity_forecast': 106,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 7.1,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 64.3},
#  {'biomass': 2.4,
#   'coal': 1.9,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '23:00',
#   'gas': 11.4,
#   'hydro': 1.2,
#   'imports': 5.8,
#   'intensity_forecast': 68,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 25.8,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 51.4},
#  {'biomass': 4.2,
#   'coal': 5.6,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '23:00',
#   'gas': 18.8,
#   'hydro': 0,
#   'imports': 3.8,
#   'intensity_forecast': 135,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 7.3,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 60.3},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN East',
#   'from': '23:00',
#   'gas': 4.3,
#   'hydro': 0,
#   'imports': 11.1,
#   'intensity_forecast': 29,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 19.7,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 64.8},
#  {'biomass': 0.2,
#   'coal': 0.2,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD South West',
#   'from': '23:00',
#   'gas': 64.9,
#   'hydro': 0.1,
#   'imports': 8.4,
#   'intensity_forecast': 260,
#   'intensity_index': 'high',
#   'month_recorded': 'January',
#   'nuclear': 0.8,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0.1,
#   'wind': 25.2},
#  {'biomass': 0.7,
#   'coal': 1.2,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SSE South',
#   'from': '23:00',
#   'gas': 25.7,
#   'hydro': 0.7,
#   'imports': 38.3,
#   'intensity_forecast': 122,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 3.2,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 30.3},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN London',
#   'from': '23:00',
#   'gas': 9.2,
#   'hydro': 0.7,
#   'imports': 40.2,
#   'intensity_forecast': 49,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 8.9,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 41},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN South East',
#   'from': '23:00',
#   'gas': 12.7,
#   'hydro': 1.1,
#   'imports': 60.6,
#   'intensity_forecast': 63,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 25.5},
#  {'biomass': 3.9,
#   'coal': 1.1,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'England',
#   'from': '23:00',
#   'gas': 14.7,
#   'hydro': 0.6,
#   'imports': 15.3,
#   'intensity_forecast': 78,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.7,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 46.7},
#  {'biomass': 1.7,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Scotland',
#   'from': '23:00',
#   'gas': 2,
#   'hydro': 9,
#   'imports': 0,
#   'intensity_forecast': 10,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 23.8,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 63.4},
#  {'biomass': 0.5,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Wales',
#   'from': '23:00',
#   'gas': 10.3,
#   'hydro': 4.2,
#   'imports': 0,
#   'intensity_forecast': 41,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 7.4,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 77.5},
#  {'biomass': 3.4,
#   'coal': 0.9,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'GB',
#   'from': '23:00',
#   'gas': 12.9,
#   'hydro': 1.9,
#   'imports': 12.5,
#   'intensity_forecast': 68,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 17.8,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 50.7},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Scottish Hydro Electric Power Distribution',
#   'from': '23:30',
#   'gas': 0,
#   'hydro': 14.7,
#   'imports': 0,
#   'intensity_forecast': 0,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 1,
#   'solar': 0,
#   'wind': 85.3},
#  {'biomass': 2.3,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SP Distribution',
#   'from': '23:30',
#   'gas': 2.8,
#   'hydro': 5.6,
#   'imports': 0,
#   'intensity_forecast': 14,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 33.9,
#   'other': 0,
#   'regionid': 2,
#   'solar': 0,
#   'wind': 55.4},
#  {'biomass': 2.7,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Electricity North West',
#   'from': '23:30',
#   'gas': 1.5,
#   'hydro': 1.2,
#   'imports': 3,
#   'intensity_forecast': 9,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 43.7,
#   'other': 0,
#   'regionid': 3,
#   'solar': 0,
#   'wind': 48},
#  {'biomass': 7.6,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'NPG North East',
#   'from': '23:30',
#   'gas': 0.4,
#   'hydro': 1.1,
#   'imports': 18.8,
#   'intensity_forecast': 12,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 61.6,
#   'other': 0,
#   'regionid': 4,
#   'solar': 0,
#   'wind': 10.5},
#  {'biomass': 22.4,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'NPG Yorkshire',
#   'from': '23:30',
#   'gas': 15.4,
#   'hydro': 0,
#   'imports': 1.1,
#   'intensity_forecast': 88,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 1.9,
#   'other': 0,
#   'regionid': 5,
#   'solar': 0,
#   'wind': 59.1},
#  {'biomass': 1.2,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SP Manweb',
#   'from': '23:30',
#   'gas': 12.2,
#   'hydro': 4.4,
#   'imports': 0.8,
#   'intensity_forecast': 49,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 21.2,
#   'other': 0,
#   'regionid': 6,
#   'solar': 0,
#   'wind': 60.2},
#  {'biomass': 0.9,
#   'coal': 0.5,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD South Wales',
#   'from': '23:30',
#   'gas': 21.4,
#   'hydro': 0.4,
#   'imports': 2.6,
#   'intensity_forecast': 92,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 6.8,
#   'other': 0,
#   'regionid': 7,
#   'solar': 0,
#   'wind': 67.3},
#  {'biomass': 2.7,
#   'coal': 1.7,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD West Midlands',
#   'from': '23:30',
#   'gas': 10.4,
#   'hydro': 1.4,
#   'imports': 7.6,
#   'intensity_forecast': 63,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 21.7,
#   'other': 0,
#   'regionid': 8,
#   'solar': 0,
#   'wind': 54.6},
#  {'biomass': 4.4,
#   'coal': 4.5,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD East Midlands',
#   'from': '23:30',
#   'gas': 12.6,
#   'hydro': 0,
#   'imports': 5.1,
#   'intensity_forecast': 102,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 9.4,
#   'other': 0,
#   'regionid': 9,
#   'solar': 0,
#   'wind': 64.1},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN East',
#   'from': '23:30',
#   'gas': 4.9,
#   'hydro': 0,
#   'imports': 12.1,
#   'intensity_forecast': 33,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 20.8,
#   'other': 0,
#   'regionid': 10,
#   'solar': 0,
#   'wind': 62.2},
#  {'biomass': 0.1,
#   'coal': 0.1,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'WPD South West',
#   'from': '23:30',
#   'gas': 70.9,
#   'hydro': 0.1,
#   'imports': 5.6,
#   'intensity_forecast': 282,
#   'intensity_index': 'very high',
#   'month_recorded': 'January',
#   'nuclear': 0.7,
#   'other': 0,
#   'regionid': 11,
#   'solar': 0,
#   'wind': 22.5},
#  {'biomass': 0.6,
#   'coal': 0.6,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'SSE South',
#   'from': '23:30',
#   'gas': 24.4,
#   'hydro': 0.7,
#   'imports': 40.7,
#   'intensity_forecast': 112,
#   'intensity_index': 'moderate',
#   'month_recorded': 'January',
#   'nuclear': 2.8,
#   'other': 0,
#   'regionid': 12,
#   'solar': 0,
#   'wind': 30.3},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN London',
#   'from': '23:30',
#   'gas': 10.8,
#   'hydro': 0.6,
#   'imports': 40.9,
#   'intensity_forecast': 56,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 7.5,
#   'other': 0,
#   'regionid': 13,
#   'solar': 0,
#   'wind': 40.2},
#  {'biomass': 0,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'UKPN South East',
#   'from': '23:30',
#   'gas': 14.6,
#   'hydro': 1,
#   'imports': 59.9,
#   'intensity_forecast': 70,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 0,
#   'other': 0,
#   'regionid': 14,
#   'solar': 0,
#   'wind': 24.5},
#  {'biomass': 4.2,
#   'coal': 0.9,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'England',
#   'from': '23:30',
#   'gas': 14,
#   'hydro': 0.6,
#   'imports': 15.6,
#   'intensity_forecast': 74,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 19.4,
#   'other': 0,
#   'regionid': 15,
#   'solar': 0,
#   'wind': 45.3},
#  {'biomass': 0.6,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Scotland',
#   'from': '23:30',
#   'gas': 1.8,
#   'hydro': 9.6,
#   'imports': 0,
#   'intensity_forecast': 8,
#   'intensity_index': 'very low',
#   'month_recorded': 'January',
#   'nuclear': 15.2,
#   'other': 0,
#   'regionid': 16,
#   'solar': 0,
#   'wind': 72.7},
#  {'biomass': 0.1,
#   'coal': 0,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'Wales',
#   'from': '23:30',
#   'gas': 13.2,
#   'hydro': 4,
#   'imports': 0,
#   'intensity_forecast': 52,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 3.9,
#   'other': 0,
#   'regionid': 17,
#   'solar': 0,
#   'wind': 78.7},
#  {'biomass': 3.5,
#   'coal': 0.7,
#   'date': '2024-01-02',
#   'day_recorded': 'Tuesday',
#   'dnoregion': 'GB',
#   'from': '23:30',
#   'gas': 12.6,
#   'hydro': 1.8,
#   'imports': 12.9,
#   'intensity_forecast': 65,
#   'intensity_index': 'low',
#   'month_recorded': 'January',
#   'nuclear': 18,
#   'other': 0,
#   'regionid': 18,
#   'solar': 0,
#   'wind': 50.5}]

# %%
import psycopg2
import yaml

with open('conn.yaml', 'r') as file:
    config = yaml.safe_load(file)

    host = config.get('host')
    user = config.get('user')
    db = config.get('database')
    password = config.get('password')
    port = config.get('port')

    conn = psycopg2.connect(
    dbname=db,
    user=user,
    password=password,
    host=host,
    port=port
)
    cur = conn.cursor()
    print('succesful!')
    for data_point in extracted_data:
        # Extract values from the data_point dictionary
        date_rec = data_point['date']
        time_rec = data_point['from']
        day_recorded = data_point['day_recorded']
        month_recorded = data_point['month_recorded']
        dnoregion = data_point['dnoregion']
        regionid = data_point['regionid']
        intensity_forecast = data_point['intensity_forecast']
        intensity_index = data_point['intensity_index']
        biomass = data_point.get('biomass')  # Use.get() to handle missing values
        coal = data_point.get('coal')
        imports = data_point.get('imports')
        gas = data_point.get('gas')
        nuclear = data_point.get('nuclear')
        other = data_point.get('other')
        hydro = data_point.get('hydro')
        solar = data_point.get('solar')
        wind = data_point.get('wind')

        # SQL query to insert data
        insert_query = """
            INSERT INTO carbon_intensity ("date", "from", day_recorded, month_recorded, dnoregion, region_id, intensity_forecast, intensity_index, biomass, coal, imports, gas, nuclear, other, hydro, solar, wind)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """

        # Execute the query with the data
        cur.execute(insert_query, (date_rec, time_rec, day_recorded, month_recorded, dnoregion, regionid, intensity_forecast, intensity_index, biomass, coal, imports, gas, nuclear, other, hydro, solar, wind))

    # Commit the changes to the database
    conn.commit()
    print("Data inserted successfully!")
# Out:
# succesful!
# Data inserted successfully!

# %%
df = pd.DataFrame(extracted_data)

# %%
df.head(20)
# Out:
#           date   from day_recorded month_recorded  \
# 0   2023-12-31  23:30       Sunday       December
# 1   2023-12-31  23:30       Sunday       December
# 2   2023-12-31  23:30       Sunday       December
# 3   2023-12-31  23:30       Sunday       December
# 4   2023-12-31  23:30       Sunday       December
# 5   2023-12-31  23:30       Sunday       December
# 6   2023-12-31  23:30       Sunday       December
# 7   2023-12-31  23:30       Sunday       December
# 8   2023-12-31  23:30       Sunday       December
# 9   2023-12-31  23:30       Sunday       December
# 10  2023-12-31  23:30       Sunday       December
# 11  2023-12-31  23:30       Sunday       December
# 12  2023-12-31  23:30       Sunday       December
# 13  2023-12-31  23:30       Sunday       December
# 14  2023-12-31  23:30       Sunday       December
# 15  2023-12-31  23:30       Sunday       December
# 16  2023-12-31  23:30       Sunday       December
# 17  2023-12-31  23:30       Sunday       December
# 18  2024-01-01  00:00       Monday        January
# 19  2024-01-01  00:00       Monday        January
#
#                                      dnoregion  regionid  intensity_forecast  \
# 0   Scottish Hydro Electric Power Distribution         1                   4
# 1                              SP Distribution         2                  24
# 2                       Electricity North West         3                   4
# 3                               NPG North East         4                  17
# 4                                NPG Yorkshire         5                  83
# 5                                    SP Manweb         6                  30
# 6                              WPD South Wales         7                  86
# 7                            WPD West Midlands         8                  52
# 8                            WPD East Midlands         9                 128
# 9                                    UKPN East        10                  19
# 10                              WPD South West        11                 281
# 11                                   SSE South        12                 118
# 12                                 UKPN London        13                  43
# 13                             UKPN South East        14                  75
# 14                                     England        15                  69
# 15                                    Scotland        16                  25
# 16                                       Wales        17                  59
# 17                                          GB        18                  63
# 18  Scottish Hydro Electric Power Distribution         1                   3
# 19                             SP Distribution         2                  23
#
#    intensity_index  biomass  coal  imports   gas  nuclear  other  hydro  \
# 0         very low      0.6   0.0      0.0   0.8      6.8      0   44.4
# 1         very low      3.7   0.0      0.1   4.8     58.6      0    0.0
# 2         very low      0.9   0.0      0.0   0.8     41.3      0    0.0
# 3         very low      9.4   0.0      2.3   1.4     73.8      0    0.0
# 4              low     25.0   0.0      0.0  13.4      0.0      0    0.0
# 5         very low      0.3   0.0      0.0   7.4     11.7      0    1.3
# 6              low      0.1   0.0      0.0  21.7      0.9      0    0.0
# 7              low      2.5   1.9      1.1   7.7     20.8      0    0.4
# 8         moderate      6.3   6.0      3.0  15.8      4.8      0    0.0
# 9         very low      0.0   0.0     12.5   2.6     20.5      0    0.0
# 10       very high      0.1   0.2      1.4  70.9      0.4      0    0.1
# 11        moderate      2.0   2.0     23.5  22.8      3.6      0    0.7
# 12             low      0.0   0.0     26.4   8.5     11.2      0    0.6
# 13             low      0.0   0.0     44.2  16.1      0.3      0    1.4
# 14             low      4.7   1.1     10.1  12.2     19.1      0    0.2
# 15        very low      1.8   0.1      0.7   5.7     29.4      0   16.8
# 16             low      0.0   0.0      0.0  15.0      0.0      0    0.0
# 17             low      4.0   0.9      8.2  11.6     19.0      0    2.2
# 18        very low      0.4   0.0      0.0   0.6      4.5      0   44.6
# 19        very low      3.4   0.0      0.0   4.8     54.6      0    0.0
#
#     solar  wind
# 0     0.0  47.4
# 1     0.0  32.7
# 2     0.0  57.1
# 3     0.0  13.1
# 4     0.0  61.6
# 5     0.0  79.2
# 6     0.0  77.3
# 7     0.0  65.8
# 8     0.0  64.2
# 9     0.0  64.4
# 10    0.0  27.0
# 11    0.0  45.3
# 12    0.0  53.2
# 13    0.0  37.9
# 14    0.0  52.6
# 15    0.0  45.6
# 16    0.0  85.0
# 17    0.0  53.9
# 18    0.0  50.0
# 19    0.0  37.2

# %%
df.shape[0]
# Out:
# 1746
